# %%
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os
import seaborn as sn

# %matplotlib inline

# %%
data_dir = "./data/"

ol = pd.read_csv(os.path.join(data_dir, "da_online_self_2020_09_24.csv"))
vc = pd.read_csv(os.path.join(data_dir, "da_virtual_2020_09_24.csv"))


eleven_grad=["darkred", "brown", "darkorange", "orange", "gold", "dodgerblue", "royalblue", "blue", "green", "forestgreen", "limegreen"]

seven_grad=["darkred", "orange", "gold", "dodgerblue", "royalblue", "green", "forestgreen"]

seven_diff=["brown", "green", "dodgerblue", "gold", "royalblue", "orange", "forestgreen"]

fsize=(8,4)

plt.rcParams["figure.dpi"]= 196
plt.rcParams['axes.labelsize'] = 12

ol.columns
# Out:
# Index(['Offering ID', 'Registration Bus Id', 'DimScopeDwKey', 'Date',
#        'Course Code', 'Course Title (en)', 'Offering Delivery Type (en)',
#        'Offering Language', 'Confirmed Registrations',
#        'Registration Status (en)', 'Organization (en)',
#        'Job Classification (group)'],
#       dtype='object')

# %%
ol["Confirmed Registrations"].replace({0 : 1}, inplace=True)

# %%
ol.head()
# Out:
#    Offering ID   Registration Bus Id  DimScopeDwKey             Date  \
# 0       127690  regdw000000004599606              2  2020-08-12 0:00
# 1       127690  regdw000000004600175              2  2020-08-12 0:00
# 2       127690  regdw000000004600392              2  2020-08-12 0:00
# 3       127690  regdw000000004600412              2  2020-08-12 0:00
# 4       127690  regdw000000004600584              2  2020-08-13 0:00
#
#   Course Code                                  Course Title (en)  \
# 0        I610  Achieving Customer-centric Design with User Pe...
# 1        I610  Achieving Customer-centric Design with User Pe...
# 2        I610  Achieving Customer-centric Design with User Pe...
# 3        I610  Achieving Customer-centric Design with User Pe...
# 4        I610  Achieving Customer-centric Design with User Pe...
#
#   Offering Delivery Type (en) Offering Language  Confirmed Registrations  \
# 0         Online - Self-paced   English/Anglais                        1
# 1         Online - Self-paced   English/Anglais                        1
# 2         Online - Self-paced   English/Anglais                        1
# 3         Online - Self-paced   English/Anglais                        1
# 4         Online - Self-paced   English/Anglais                        1
#
#   Registration Status (en)                   Organization (en)  \
# 0                Confirmed               Canada Revenue Agency
# 1                Confirmed       Canada Border Services Agency
# 2                Confirmed  Department of Fisheries and Oceans
# 3                Confirmed               Global Affairs Canada
# 4                Confirmed                   Statistics Canada
#
#   Job Classification (group)
# 0                         AU
# 1                         FB
# 2                         CR
# 3                       LEGS
# 4                         CR

# %%
ol.groupby(ol["Course Title (en)"])["Confirmed Registrations"].sum()
# Out:
# Course Title (en)
# Achieving Customer-centric Design with User Personas (I610)           58
# Achieving Digital Dexterity (I631)                                   125
# Agile Principles and Methodologies (I632)                             53
# Agile Project Planning (I503)                                         45
# Agile Project Scheduling and Monitoring (I633)                        61
# Agile Stakeholder Engagement and Team Development (I558)              21
# Applying Virtual Assistant Technology (I615)                          47
# Best Practices for Digital Transformation (I502)                      41
# Big Data Fundamentals (I520)                                          22
# Big Data Interpretation (I521)                                         2
# Building a Culture of Design Thinking (I605)                          31
# Connecting with the Internet of Things (I611)                         21
# Creating Engagement with Virtual Reality (I613)                       27
# Cultivating Cross-functional Team Collaboration (I634)                25
# Cultivating Enterprise Agile (I635)                                   15
# Developing and Supporting an Agile Mind-set (I557)                    24
# Embracing an Agile Culture for Business Growth (I556)                  9
# Embracing the Cloud for Business Efficiency (I623)                    39
# Enabling Business-IT Collaboration and Strategic Alignment (I636)     10
# Exploring Customer Journey Mapping (I607)                             18
# Exploring Data Visualization (I519)                                   26
# Exploring the Relationship between UI/UX Design (I609)                 6
# Getting Started with Machine Learning (I630)                          11
# Harnessing the Power of Data Science for Business Growth (I522)        6
# How Blockchain Technology is Transforming Businesses (I612)           10
# Making Data-driven Decisions (I514)                                   28
# Reaching Efficient Solutions w Computational Thinking (I637)           8
# The Essential Role of the Agile Product Owner (I638)                   9
# Transforming the Workplace Using Artificial Intelligence (I629)        9
# Turning Social Intelligence into Actionable Insight (I524)            13
# Using Augmented Reality for Organizational Gains (I614)                8
# Name: Confirmed Registrations, dtype: int64

# %%
ol["Confirmed Registrations"].sum()
# Out:
# 828

# %%
ol.groupby(ol["Course Code"])["Confirmed Registrations"].sum().plot(kind="bar", title="DA Count by Online Offering", figsize=fsize, rot=45)

# %%
vc.head()
# Out:
#    Offering ID             Date Course Code  \
# 0       127118  2020-07-09 0:00        I500
# 1       127119  2020-07-17 0:00        I500
# 2       127120  2020-07-29 0:00        I500
# 3       127121  2020-08-06 0:00        I500
# 4       127122  2020-08-18 0:00        I500
#
#                         Course Title (en) Offering Delivery Type (en)  \
# 0  Discover Digital for Executives (I500)           Virtual Classroom
# 1  Discover Digital for Executives (I500)           Virtual Classroom
# 2  Discover Digital for Executives (I500)           Virtual Classroom
# 3  Discover Digital for Executives (I500)           Virtual Classroom
# 4  Discover Digital for Executives (I500)           Virtual Classroom
#
#   Offering Language     Offering Status  Confirmed Registrations  \
# 0   English/Anglais  Delivered - Normal                       11
# 1   English/Anglais  Delivered - Normal                       11
# 2   English/Anglais  Delivered - Normal                       11
# 3   English/Anglais  Delivered - Normal                        9
# 4   English/Anglais  Cancelled - Normal                        0
#
#                        Instructor Name
# 0                    Elizabeth McKeown
# 1    Elizabeth McKeown, Richard Landry
# 2  Elizabeth McKeown, Jean-Marc Dupont
# 3  Elizabeth McKeown, Jean-Marc Dupont
# 4                              Unknown

# %%
vc.groupby(vc["Course Code"])["Confirmed Registrations"].sum().plot(kind="bar", title="DA Count by Virtual Class Offering", figsize=fsize, rot=45)

# %%
vc.groupby(vc["Course Code"])["Confirmed Registrations"].sum()
# Out:
# Course Code
# I500    160
# I501      4
# I602    341
# I621    172
# Name: Confirmed Registrations, dtype: int64

# %%
vc["Confirmed Registrations"].sum()
# Out:
# 677

# %%
vc["Confirmed Registrations"]
# Out:
# 0     11
# 1     11
# 2     11
# 3      9
# 4      0
# 5     16
# 6     23
# 7      9
# 8      0
# 9      8
# 10     3
# 11    12
# 12    11
# 13     1
# 14     0
# 15     0
# 16    41
# 17    24
# 18    67
# 19    40
# 20    27
# 21     9
# 22     3
# 23    12
# 24    22
# 25    16
# 26    26
# 27    24
# 28    24
# 29    26
# 30    24
# 31    24
# 32    24
# 33    24
# 34    17
# 35    11
# 36     1
# 37    26
# 38    23
# 39     1
# 40     1
# 41    15
# Name: Confirmed Registrations, dtype: int64

# %%
vc.groupby([vc["Course Code"], vc["Offering Status"]]).sum()
# Out:
#                                 Offering ID  Confirmed Registrations
# Course Code Offering Status
# I500        Cancelled - Normal       381405                        0
#             Delivered - Normal      1016993                       90
#             Open - Normal            637671                       70
# I501        Cancelled - Normal       127135                        0
#             Open - Normal            254263                        4
# I602        Delivered - Normal       255915                       28
#             Open - Normal           2176479                      313
# I621        Open - Normal            508757                      172

# %%
vc.groupby([vc["Course Code"], vc["Offering Status"]])["Confirmed Registrations"].sum().plot(kind="bar", title="DA Virtual Class Offering Status", figsize=fsize, rot=45)

# %%
learners = pd.read_csv(os.path.join(data_dir, "da_learner_v2_2020_09_24.csv"))

# %%
learners.describe()
# Out:
#        Registration No Show Flag
# count                1488.000000
# mean                    0.026882
# std                     0.161792
# min                     0.000000
# 25%                     0.000000
# 50%                     0.000000
# 75%                     0.000000
# max                     1.000000

# %%
learners.head()
# Out:
#                                      Department (en) Learner Province (en)  \
# 0  Administrative Tribunals Support Service of Ca...           Ontario_NCR
# 1  Administrative Tribunals Support Service of Ca...           Ontario_NCR
# 2  Administrative Tribunals Support Service of Ca...           Ontario_NCR
# 3  Administrative Tribunals Support Service of Ca...           Ontario_NCR
# 4  Administrative Tribunals Support Service of Ca...           Ontario_NCR
#
#               Date Course Code                            Course Title (en)  \
# 0  2020-07-29 0:00        I500       Discover Digital for Executives (I500)
# 1  2020-09-14 0:00        I500       Discover Digital for Executives (I500)
# 2  2020-09-21 0:00        I500       Discover Digital for Executives (I500)
# 3  2020-10-05 0:00        I621  Getting Started with Cloud Computing (I621)
# 4  2020-10-14 0:00        I500       Discover Digital for Executives (I500)
#
#   Offering Delivery Type (en) Offering Language  Registration No Show Flag  \
# 0           Virtual Classroom   English/Anglais                          0
# 1           Virtual Classroom   English/Anglais                          0
# 2           Virtual Classroom   French/Français                          0
# 3           Virtual Classroom   French/Français                          0
# 4           Virtual Classroom   English/Anglais                          0
#
#   Registration Status (en)     Offering Status  \
# 0                Confirmed  Delivered - Normal
# 1                Cancelled  Delivered - Normal
# 2                Confirmed  Delivered - Normal
# 3                Cancelled       Open - Normal
# 4                Confirmed       Open - Normal
#
#                        Instructor Name
# 0  Elizabeth McKeown, Jean-Marc Dupont
# 1   Elizabeth McKeown, Felicity Mulgan
# 2      Daniel Richer, Jean-Marc Dupont
# 3                              Unknown
# 4                    Elizabeth McKeown

# %%
learners.groupby(learners["Course Code"])["Date"].count()
# Out:
# Course Code
# I500    257
# I501      5
# I502     41
# I503     45
# I514     28
# I519     26
# I520     22
# I521      2
# I522      5
# I524     13
# I556      6
# I557     24
# I558     21
# I602    324
# I605     31
# I607     13
# I609      6
# I610     56
# I611     20
# I612     10
# I613     25
# I614      8
# I615     46
# I621    110
# I623     37
# I629      9
# I630      4
# I631    122
# I632     52
# I633     59
# I634     19
# I635     15
# I636     10
# I637      8
# I638      9
# Name: Date, dtype: int64

# %%
learners
# Out:
#                                         Department (en) Learner Province (en)  \
# 0     Administrative Tribunals Support Service of Ca...           Ontario_NCR
# 1     Administrative Tribunals Support Service of Ca...           Ontario_NCR
# 2     Administrative Tribunals Support Service of Ca...           Ontario_NCR
# 3     Administrative Tribunals Support Service of Ca...           Ontario_NCR
# 4     Administrative Tribunals Support Service of Ca...           Ontario_NCR
# ...                                                 ...                   ...
# 1483                                            Unknown            Québec_NCR
# 1484                                            Unknown            Québec_NCR
# 1485                                            Unknown            Québec_NCR
# 1486                                            Unknown               Unknown
# 1487                   Veterans Review and Appeal Board  Prince Edward Island
#
#                  Date Course Code  \
# 0     2020-07-29 0:00        I500
# 1     2020-09-14 0:00        I500
# 2     2020-09-21 0:00        I500
# 3     2020-10-05 0:00        I621
# 4     2020-10-14 0:00        I500
# ...               ...         ...
# 1483  2020-09-14 0:00        I632
# 1484  2020-09-22 0:00        I558
# 1485  2020-10-05 0:00        I621
# 1486  2020-09-09 0:00        I632
# 1487  2020-08-17 0:00        I631
#
#                                       Course Title (en)  \
# 0                Discover Digital for Executives (I500)
# 1                Discover Digital for Executives (I500)
# 2                Discover Digital for Executives (I500)
# 3           Getting Started with Cloud Computing (I621)
# 4                Discover Digital for Executives (I500)
# ...                                                 ...
# 1483          Agile Principles and Methodologies (I632)
# 1484  Agile Stakeholder Engagement and Team Developm...
# 1485        Getting Started with Cloud Computing (I621)
# 1486          Agile Principles and Methodologies (I632)
# 1487                 Achieving Digital Dexterity (I631)
#
#      Offering Delivery Type (en) Offering Language  Registration No Show Flag  \
# 0              Virtual Classroom   English/Anglais                          0
# 1              Virtual Classroom   English/Anglais                          0
# 2              Virtual Classroom   French/Français                          0
# 3              Virtual Classroom   French/Français                          0
# 4              Virtual Classroom   English/Anglais                          0
# ...                          ...               ...                        ...
# 1483         Online - Self-paced   English/Anglais                          0
# 1484         Online - Self-paced   English/Anglais                          0
# 1485           Virtual Classroom   French/Français                          0
# 1486         Online - Self-paced   French/Français                          0
# 1487         Online - Self-paced   English/Anglais                          0
#
#      Registration Status (en)     Offering Status  \
# 0                   Confirmed  Delivered - Normal
# 1                   Cancelled  Delivered - Normal
# 2                   Confirmed  Delivered - Normal
# 3                   Cancelled       Open - Normal
# 4                   Confirmed       Open - Normal
# ...                       ...                 ...
# 1483                Confirmed                 N/a
# 1484                Cancelled                 N/a
# 1485                Confirmed       Open - Normal
# 1486                Confirmed                 N/a
# 1487                Cancelled                 N/a
#
#                           Instructor Name
# 0     Elizabeth McKeown, Jean-Marc Dupont
# 1      Elizabeth McKeown, Felicity Mulgan
# 2         Daniel Richer, Jean-Marc Dupont
# 3                                 Unknown
# 4                       Elizabeth McKeown
# ...                                   ...
# 1483                              Unknown
# 1484                              Unknown
# 1485                              Unknown
# 1486                              Unknown
# 1487                              Unknown
#
# [1488 rows x 11 columns]

# %%
pd.set_option('display.max_rows', None)
learners.groupby("Department (en)")["Date"].count()
# Out:
# Department (en)
# Administrative Tribunals Support Service of Canada                       6
# Atlantic Canada Opportunities Agency                                     4
# Canada Border Services Agency                                           19
# Canada Council for the Arts                                              1
# Canada Revenue Agency                                                  214
# Canada School of Public Service                                         61
# Canadian Environmental Assessment Agency                                 4
# Canadian Food Inspection Agency                                         33
# Canadian Grain Commission                                                3
# Canadian Human Rights Commission                                         2
# Canadian Institutes of Health Research                                   2
# Canadian Nuclear Safety Commission                                       3
# Canadian Radio-television and Telecommunications Commission              2
# Canadian Space Agency                                                   11
# Canadian Transportation Accident Investigation and Safety Board          2
# Canadian Transportation Agency                                           6
# Communications Security Establishment                                   24
# Correctional Service of Canada                                          17
# Courts Administration Service                                            5
# Crown-Indigenous Relations and Northern Affairs Canada                   7
# Department of Agriculture and Agri-Food                                 24
# Department of Canadian Heritage                                         11
# Department of Citizenship and Immigration                               38
# Department of Employment and Social Development                        114
# Department of Finance                                                    6
# Department of Fisheries and Oceans                                      29
# Department of Foreign Affairs, Trade and Development                    77
# Department of Health                                                    31
# Department of Indigenous Services Canada                                17
# Department of Industry                                                  22
# Department of Justice                                                   18
# Department of National Defence (military members)                       12
# Department of National Defence (public servants)                        88
# Department of Natural Resources (includes Northern Pipeline Agency)     21
# Department of Public Safety and Emergency Preparedness                  18
# Department of Public Works and Government Services                      72
# Department of Transport                                                 35
# Department of Veterans Affairs                                          48
# Department of Western Economic Diversification                           1
# Economic Development Agency of Canada for the Regions of Quebec          7
# Environment and Climate Change Canada                                   48
# Federal Economic Development Agency for Southern Ontario                 4
# Financial Transactions and Reports Analysis Centre of Canada             9
# Immigration and Refugee Board                                           18
# Indian Oil and Gas Canada                                                1
# Library and Archives of Canada                                          11
# Military Grievances External Review Committee                            1
# Military Police Complaints Commission                                    6
# National Capital Commission                                              1
# National Energy Board                                                    2
# National Research Council of Canada                                     12
# Natural Sciences and Engineering Research Council                        4
# Office of Infrastructure of Canada                                       4
# Office of the Auditor General of Canada                                  3
# Office of the Chief Electoral Officer                                    5
# Office of the Commissioner of Official Languages                         1
# Office of the Director of Public Prosecutions                            1
# Office of the Privacy Commissioner of Canada                             1
# Office of the Superintendent of Financial Institutions                   9
# Parks Canada Agency                                                     18
# Privy Council Office                                                     4
# Public Health Agency of Canada                                          20
# Public Service Commission                                               16
# Royal Canadian Mounted Police (force members and civilian members)       1
# Royal Canadian Mounted Police (public servants)                         18
# Shared Services Canada                                                  49
# Social Sciences and Humanities Research Council                          2
# Statistics Canada                                                       39
# Treasury Board                                                          36
# Unknown                                                                 28
# Veterans Review and Appeal Board                                         1
# Name: Date, dtype: int64

# %%
learners.groupby("Learner Province (en)")["Date"].count()
# Out:
# Learner Province (en)
# Alberta                       45
# British Columbia             114
# Manitoba                      45
# NCR/RCN                       18
# New Brunswick                 26
# Newfoundland and Labrador     10
# Nova Scotia                   39
# Ontario                      218
# Ontario_NCR                  511
# Outside Canada                43
# Prince Edward Island          33
# Quebec                       112
# Québec_NCR                   257
# Saskatchewan                  14
# Unknown                        1
# Yukon                          2
# Name: Date, dtype: int64

# %%
learners.groupby(learners["Course Title (en)"].where(learners["Registration No Show Flag"] == 1))["Date"].count()
# Out:
# Course Title (en)
# Digital in Practice (I602)                 8
# Discover Digital for Executives (I500)    32
# Name: Date, dtype: int64

# %%
evals = pd.read_csv(os.path.join(data_dir, "da_satisfaction.csv"))

# %%
evals.head()
# Out:
#   Offering Start Date Course Code  \
# 0     2020-07-29 0:00        I500
# 1     2020-07-29 0:00        I500
# 2     2020-09-08 0:00        I602
# 3     2020-09-10 0:00        I502
# 4     2020-09-15 0:00        I602
#
#                                 Course Title Descr. Offering DeliveryType_EN  \
# 0            Discover Digital for Executives (I500)        Virtual Classroom
# 1            Discover Digital for Executives (I500)        Virtual Classroom
# 2                        Digital in Practice (I602)        Virtual Classroom
# 3  Best Practices for Digital Transformation (I502)      Online - Self-paced
# 4                        Digital in Practice (I602)        Virtual Classroom
#
#   Offering Language Question Code  \
# 0   English/Anglais           Q01
# 1   English/Anglais           Q01
# 2   English/Anglais           Q01
# 3   English/Anglais           Q01
# 4   French/Français           Q01
#
#                                             Question  Answer
# 0  1. Please rate your overall satisfaction or di...      10
# 1  1. Please rate your overall satisfaction or di...       8
# 2  1. Please rate your overall satisfaction or di...       6
# 3  1. Please rate your overall satisfaction or di...       3
# 4  1. Please rate your overall satisfaction or di...       9

# %%
evals.groupby("Course Title Descr.")["Answer"].count()
# Out:
# Course Title Descr.
# Achieving Customer-centric Design with User Personas (I610)         4
# Achieving Digital Dexterity (I631)                                  5
# Agile Project Planning (I503)                                       1
# Agile Stakeholder Engagement and Team Development (I558)            2
# Applying Virtual Assistant Technology (I615)                        3
# Best Practices for Digital Transformation (I502)                    3
# Big Data Interpretation (I521)                                      1
# Cultivating Enterprise Agile (I635)                                 1
# Digital in Practice (I602)                                          9
# Discover Digital for Executives (I500)                             13
# Embracing the Cloud for Business Efficiency (I623)                  1
# Exploring Data Visualization (I519)                                 2
# Harnessing the Power of Data Science for Business Growth (I522)     1
# How Blockchain Technology is Transforming Businesses (I612)         1
# Making Data-driven Decisions (I514)                                 1
# Name: Answer, dtype: int64

# %%
evals.groupby("Course Title Descr.")["Answer"].agg("mean")
# Out:
# Course Title Descr.
# Achieving Customer-centric Design with User Personas (I610)        10.000000
# Achieving Digital Dexterity (I631)                                  6.000000
# Agile Project Planning (I503)                                       2.000000
# Agile Stakeholder Engagement and Team Development (I558)            8.500000
# Applying Virtual Assistant Technology (I615)                        9.666667
# Best Practices for Digital Transformation (I502)                    7.333333
# Big Data Interpretation (I521)                                      8.000000
# Cultivating Enterprise Agile (I635)                                 7.000000
# Digital in Practice (I602)                                          7.444444
# Discover Digital for Executives (I500)                              7.846154
# Embracing the Cloud for Business Efficiency (I623)                  8.000000
# Exploring Data Visualization (I519)                                 9.500000
# Harnessing the Power of Data Science for Business Growth (I522)     7.000000
# How Blockchain Technology is Transforming Businesses (I612)        10.000000
# Making Data-driven Decisions (I514)                                10.000000
# Name: Answer, dtype: float64

# %%
evals.describe()
# Out:
#           Answer
# count  48.000000
# mean    7.875000
# std     2.489339
# min     1.000000
# 25%     7.000000
# 50%     9.000000
# 75%    10.000000
# max    10.000000
